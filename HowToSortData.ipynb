# %% [markdown]
# # How to Filter and Visualize Data Using Excel:
#
# Topics Covered:
# * How to **read** a dataset.
# * How to calculate data **statistics**.
# * How to **filter/sort** a dataset.
# * How to make **visualizations**.
#
# ## What is Excel?
#
# Excel is a useful tool to format and visualize data.
# * sort data
# * create graphs out of data
# * perform a variety of function
#     * ex. Median, Length, Concatenate, etc.
#
# ## Project Question:
#
# Did the **Total Dissolved Solids** (TDS) in the River **Change** Over Time?
#
# *Total Dissolved Solids*
# : a measure of the dissolved combined content of all inorganic and organic substances present in a liquid in molecular, ionized, or micro-granular suspended form.
#
# | TDS Level (mg/L) | TDS Rating for Safe Drinking |
# | :------| :-----------|
# | Less than 300   | Excellent |
# | 300 - 600 | Good |
# | 600 - 900 | Fair |
# | 900 - 1200 | Poor |
# | 1200 | Unacceptable |
#
# ## The Data Used in Project
# * Sample Data:
#     * [data found here](https://nwis.waterdata.usgs.gov/nwis/qwdata/?site_no=11042000)
#
# * Practical Data:
#     * [data found here](https://data.cnra.ca.gov/dataset/water-quality-data/resource/a9e7ef50-54c3-4031-8e44-aa46f3c660fe)

# %% [markdown]
# ## How to Read a Dataset
# * Many datasets are shown in the following format:
# [SampleDataset.csv](./Data/SampleDataset.csv)
# * How is it **organized**?
#     * The **first line** in the dataset displays the list of **parameters** the dataset measures:
#
#   ` "Regulating Agency","Water System Number","Water System Name","System Status","Water System Classification","Principal County Served","Population Served","Service Connections","PS Code","Sampling Point Name","Facility Type","Facility Status","Sample Date","Sample Time","Analysis Date","ELAP Cert#","Lab Name","Analyte Code","Analyte Name","Result","Counting Error","Units of Measure","Less Than Reporting Level","Reporting Level","DLR","MCL","Method" `
#
#     * The **second line and below** display the results of a data **sample entry**.
#
#     * Excel will sort data in the following fashion:

# %% [markdown]
# | Regulating Agency            | Water System Number | Water System Name              | System Status | Water System Classification | Principal County Served | Population Served | Service Connections | PS Code             | Sampling Point Name | Facility Type | Facility Status | Sample Date | Sample Time | Analysis Date | ELAP Cert# | Lab Name                              | Analyte Code | Analyte Name                  | Result | Counting Error | Units of Measure | Less Than Reporting Level | Reporting Level | DLR | MCL | Method    |
# | ---------------------------- | ------------------- | ------------------------------ | ------------- | --------------------------- | ----------------------- | ----------------- | ------------------- | ------------------- | ------------------- | ------------- | --------------- | ----------- | ----------- | ------------- | ---------- | ------------------------------------- | ------------ | ----------------------------- | ------ | -------------- | ---------------- | ------------------------- | --------------- | --- | --- | --------- |
# | DISTRICT 17 - SANTA CLARA    | CA4300615           | THOUSAND TRAILS - MORGAN HILL  | A             | C                           | SANTA CLARA             | 508               | 320                 | CA4300615\_001\_001 | WELL 01             | WL            | A               | 12/31/2021  | 06:56:00    | 1/1/2022      | 2385       | MONTEREY BAY ANALYTICAL SERVICES      | 1041         | NITRITE                       |        |                | MG/L             | Y                         | 0.1             |     |     | EPA 300.0 |
# | DISTRICT 17 - SANTA CLARA    | CA4300615           | THOUSAND TRAILS - MORGAN HILL  | A             | C                           | SANTA CLARA             | 508               | 320                 | CA4300615\_001\_001 | WELL 01             | WL            | A               | 12/31/2021  | 06:56:00    | 1/1/2022      | 2385       | MONTEREY BAY ANALYTICAL SERVICES      | 1040         | NITRATE                       | 0.4    |                | MG/L             | N                         | 0.1             |     |     | EPA 300.0 |
# | DISTRICT 19 - TEHACHAPI      | CA1500424           | LANDS OF PROMISE MWC           | A             | C                           | KERN                    | 174               | 63                  | CA1500424\_005\_005 | WELL 05             | WL            | A               | 12/31/2021  | 16:25:00    | 12/31/2021    | 2791       | ZALCO LABORATORIES, INC.              | 1040         | NITRATE                       | 0.36   |                | MG/L             | N                         | 0.1             |     |     | EPA 300.0 |
# | DISTRICT 19 - TEHACHAPI      | CA1500424           | LANDS OF PROMISE MWC           | A             | C                           | KERN                    | 174               | 63                  | CA1500424\_006\_006 | WELL 06             | WL            | A               | 12/31/2021  | 16:30:00    | 12/31/2021    | 2791       | ZALCO LABORATORIES, INC.              | 1040         | NITRATE                       | 0.34   |                | MG/L             | N                         | 0.1             |     |     | EPA 300.0 |
# | DISTRICT 05 - MONTEREY       | CA2790002           | MONTEREY ONE WATER             | A             | NP                          | MONTEREY                | 0                 |                     | CA2790002\_300\_300 | AWPF EFFLUENT       | TP            | A               | 12/31/2021  | 07:14:00    | 1/5/2022      | 2385       | MONTEREY BAY ANALYTICAL SERVICES      | 1038         | NITRATE-NITRITE               |        |                | MG/L             | Y                         | 0.4             |     |     | EPA 300.0 |
# | DISTRICT 13 - SAN BERNARDINO | CA3610002           | ALPINE WATER USERS ASSOCIATION | A             | C                           | SAN BERNARDINO          | 2534              | 931                 | CA3610002\_016\_016 | WELL 1 IX FINISHED  | TP            | A               | 12/31/2021  | 07:34:00    | 1/7/2022      | 1088       | CLINICAL LABORATORY OF SAN BERNARDINO | 4109         | GROSS ALPHA PARTICLE ACTIVITY |        | 0.63           | PCI/L            | Y                         | 3               |     |     | SM 7110 C |
# | DISTRICT 13 - SAN BERNARDINO | CA3610002           | ALPINE WATER USERS ASSOCIATION | A             | C                           | SAN BERNARDINO          | 2534              | 931                 | CA3610002\_016\_016 | WELL 1 IX FINISHED  | TP            | A               | 12/31/2021  | 07:34:00    | 1/4/2022      | 1088       | CLINICAL LABORATORY OF SAN BERNARDINO | 4006         | COMBINED URANIUM              | 3.3    | 0              | PCI/L            | N                         | 1               |     |     | EPA 200.8 |
# | DISTRICT 19 - TEHACHAPI      | CA1500424           | LANDS OF PROMISE MWC           | A             | C                           | KERN                    | 174               | 63                  | CA1500424\_005\_005 | WELL 05             | WL            | A               | 12/31/2021  | 04:25:00    | 1/5/2022      | 1132       | WECK LABORATORIES                     | 1930         | TDS                           | 210    |                | MG/L             | N                         | 10              |     |     | SM 2540 C |
# | DISTRICT 19 - TEHACHAPI      | CA1500424           | LANDS OF PROMISE MWC           | A             | C                           | KERN                    | 174               | 63                  | CA1500424\_005\_005 | WELL 05             | WL            | A               | 12/31/2021  | 04:25:00    | 1/7/2022      | 1132       | WECK LABORATORIES                     | 1927         | ALKALINITY, TOTAL             | 91     |                | MG/L             | N                         | 5               |     |     | SM 2320 B |

# %% [markdown]
# # PracticalSample Data
# * Data that we will be using: [PracticeWaterData](Data/PracticeDataset.csv)
#
# |station_id|station_name        |full_station_name                |station_number|station_type |latitude|longitude|status               |county_name|sample_code |sample_date     |sample_depth|sample_depth_units|parameter             |result|reporting_limit|units        |method_name            |
# |----------|--------------------|---------------------------------|--------------|-------------|--------|---------|---------------------|-----------|------------|----------------|------------|------------------|----------------------|------|---------------|-------------|-----------------------|
# |5713      |SAN LUIS REY R UNDER|SAN LUIS REY R UNDER HWY 101 BR  |X3108010      |Surface Water|33.2036 |-117.387 |Review Status Unknown|San Diego  |WDIS_0967844|1/19/1955 15:15 |            |Feet              |Total Dissolved Solids|476   |1              |mg/L at 105 �|UnkH TDS               |
# |5715      |SAN LUIS REY R 0.25 |SAN LUIS REY R 0.25 MI AB HWY 101|X3108550      |Surface Water|33.2067 |-117.3848|Review Status Unknown|San Diego  |WDIS_0967846|3/26/1954 14:00 |            |Feet              |Total Dissolved Solids|9020  |1              |mg/L at 180 �|UnkH TDS               |
# |5716      |SAN LUIS REY R A G S|SAN LUIS REY R A G S 0.5 MI E 101|X3110000      |Surface Water|33.2111 |-117.3775|Review Status Unknown|San Diego  |WDIS_0967848|2/3/1958 10:00  |            |Feet              |Total Dissolved Solids|222   |1              |mg/L at 180 �|Std Method 10th Ed, TDS|
# |5716      |SAN LUIS REY R A G S|SAN LUIS REY R A G S 0.5 MI E 101|X3110000      |Surface Water|33.2111 |-117.3775|Review Status Unknown|San Diego  |WDIS_0967850|2/9/1962 17:00  |            |Feet              |Total Dissolved Solids|380   |1              |mg/L at 180 �|UnkMod TDS             |
# |5720      |PILGRAM C TRIB TO SA|PILGRAM C TRIB TO SAN LUIS REY R |X3112020      |Surface Water|33.2436 |-117.3489|Review Status Unknown|San Diego  |WDIS_0967856|3/22/1958 00:00 |            |Feet              |Total Dissolved Solids|140   |1              |mg/L at 180 �|UnkMod TDS             |
# |5721      |SAN LUIS REY R TRIB-|SAN LUIS REY R TRIB-SMALL LK SW F|X3112110      |Surface Water|33.2417 |-117.3364|Review Status Unknown|San Diego  |WDIS_0967858|11/27/1957 00:00|            |Feet              |Total Dissolved Solids|2210  |1              |mg/L at 105 �|UnkMod TDS             |
# |5732      |SAN LUIS REY R NR BO|SAN LUIS REY R NR BONSALL        |X3117500      |Surface Water|33.255  |-117.2489|Review Status Unknown|San Diego  |WDIS_0967888|4/3/1951 00:00  |            |Feet              |Total Dissolved Solids|757   |1              |mg/L at 105 �|UnkH TDS               |
# |5736      |SAN LUIS REY R A BON|SAN LUIS REY R A BONSALL         |X3123000      |Surface Water|33.2881 |-117.2225|Review Status Unknown|San Diego  |WDIS_0967906|1/8/1949 00:00  |            |Feet              |Total Dissolved Solids|613   |1              |mg/L at 105 �|UnkH TDS               |
# |5736      |SAN LUIS REY R A BON|SAN LUIS REY R A BONSALL         |X3123000      |Surface Water|33.2881 |-117.2225|Review Status Unknown|San Diego  |WDIS_0967907|3/22/1958 00:00 |            |Feet              |Total Dissolved Solids|300   |1              |mg/L at 180 �|Std Method 10th Ed, TDS|
# |5736      |SAN LUIS REY R A BON|SAN LUIS REY R A BONSALL         |X3123000      |Surface Water|33.2881 |-117.2225|Review Status Unknown|San Diego  |WDIS_0967908|3/28/1958 15:30 |            |Feet              |Total Dissolved Solids|780   |1              |mg/L at 180 �|Std Method 10th Ed, TDS|
# |5736      |SAN LUIS REY R A BON|SAN LUIS REY R A BONSALL         |X3123000      |Surface Water|33.2881 |-117.2225|Review Status Unknown|San Diego  |WDIS_0967909|7/19/1958 20:10 |            |Feet              |Total Dissolved Solids|691   |1              |mg/L at 180 �|UnkMod TDS             |
# |5740      |SAN LUIS REY R A HWY|SAN LUIS REY R A HWY 395         |X3125880      |Surface Water|33.3217 |-117.1609|Review Status Unknown|San Diego  |WDIS_0967921|3/28/1958 15:00 |            |Feet              |Total Dissolved Solids|325   |1              |mg/L at 180 �|Std Method 10th Ed, TDS|
# |5740      |SAN LUIS REY R A HWY|SAN LUIS REY R A HWY 395         |X3125880      |Surface Water|33.3217 |-117.1609|Review Status Unknown|San Diego  |WDIS_0967922|4/21/1958 17:30 |            |Feet              |Total Dissolved Solids|418   |1              |mg/L at 180 �|UnkMod TDS             |
# |5741      |SAN LUIS REY R A MON|SAN LUIS REY R A MONSERATE NARROW|X3130000      |Surface Water|33.337  |-117.1356|Review Status Unknown|San Diego  |WDIS_0967923|1/8/1949 00:00  |            |Feet              |Total Dissolved Solids|324   |1              |mg/L at 105 �|UnkH TDS               |
# |5741      |SAN LUIS REY R A MON|SAN LUIS REY R A MONSERATE NARROW|X3130000      |Surface Water|33.337  |-117.1356|Review Status Unknown|San Diego  |WDIS_0967925|4/3/1951 00:00  |            |Feet              |Total Dissolved Solids|458   |1              |mg/L at 105 �|UnkH TDS               |
# |5741      |SAN LUIS REY R A MON|SAN LUIS REY R A MONSERATE NARROW|X3130000      |Surface Water|33.337  |-117.1356|Review Status Unknown|San Diego  |WDIS_0967924|10/21/1949 12:00|            |Feet              |Total Dissolved Solids|370   |1              |mg/L at 105 �|UnkH TDS               |
# |5742      |SAN LUIS REY R XING |SAN LUIS REY R XING A MONSERATE  |X3130610      |Surface Water|33.34   |-117.1314|Review Status Unknown|San Diego  |WDIS_0967933|5/2/1958 11:15  |            |Feet              |Total Dissolved Solids|396   |1              |mg/L at 180 �|UnkMod TDS             |
# |5746      |SAN LUIS REY R TRIB |SAN LUIS REY R TRIB TO GOMEZ     |X3133030      |Surface Water|33.38   |-117.0825|Review Status Unknown|San Diego  |WDIS_0967937|3/22/1962 17:00 |            |Feet              |Total Dissolved Solids|220   |1              |mg/L at 180 �|UnkMod TDS             |
# |5747      |UNNAMED TRIB TO SAN |UNNAMED TRIB TO SAN LUIS REY R   |X3134010      |Surface Water|33.3889 |-117.0659|Review Status Unknown|San Diego  |WDIS_0967938|5/5/1955 13:30  |            |Feet              |Total Dissolved Solids|402   |1              |mg/L at 105 �|UnkH TDS               |

# %% [markdown]
# ## (Sample) How to Filter/Sort a Dataset
# Goal:
# * We want to filter out the data to show samples from oldest to newest.
#
# Step 1:
# * CLick on 'Data' -> 'Filter'.
#
# ![SampleFilter.png](ExcelPics/SampleFilter.png)
#
# Step 2:
# * Click on the downarrow on the right of the 'sample_date' cell, then 'Sort Oldest to Newest'
#
# ![SampleSort.png](ExcelPics/SampleSort.png)
#
# * The dataset will now be filtered to show samples in order by date.
#
# ![SampleResult.png](ExcelPics/SampleResult.png)

# %% [markdown]
# ## (Sample) How to Make Visualizations
# * Data visulaizations (through maps and graphs) are a great way to see the patterns, trends, and outliers of the data.
#
# Using the filtered [PracticeWaterData](Data/PracticeDataset.csv) dataset, we want to compare TDS and time.
#
# Step 1: Create the graph.
#
# * Click on 'Insert' -> Scatter Picture -> 2nd Scatter Picture.
#
# ![SampleScatter.png](ExcelPics/SampleScatter.png)
#
# * Click on 'Chart Design' -> 'Select Data'
#
# ![SampleSelectData.png](ExcelPics/SampleSelectData.png)
#
# * Click on 'Add'.
#
# ![SampleAdd.png](ExcelPics/SampleAdd.png)
#
# * Fill in the 'Series X values' and 'Series Y values' textbox with the following text, then click on 'ok'.
#
# ![SampleValues.png](ExcelPics/SampleValues.png)
#
# Step 2: Set trendline and its equation
#
# * Click on 'Quick Layout' -> 'Layout 3'.
#
# ![SamplePlot.png](ExcelPics/SamplePlot.png)
#
# * Click on 'Add Chart Element' -> 'Trendline' -> 'More Trendline Options'
#
# ![SampleTrendlineOptions.png](ExcelPics/SampleTrendlineOptions.png)
#
# * Click on the 'Display Equation on Chart' textbox.
#
# ![SampleTrendlineCheckbox.png](ExcelPics/SampleTrendlineCheckbox.png)
#
# * Result:
#
# ![SampleGraphResult.png](ExcelPics/SampleGraphResult.png)

# %% [markdown]
# ## (Sample) Calculate Data Statistics
# * Data Statistics such as mean, median, and range of data can be easily found on Excel.
#
# Mean : is the average of a data set.
#
# * To find the mean of the whole sample result, enter in a new cell:
#
#     Equation Info: =AVERAGE(*AVERAGE_RANGE*)
#
#     Our Dataset: =AVERAGE(O:O)
#
# ![SampleAverage.png](ExcelPics/SampleAverage.png)
#
# Median : is the middle value of the data ordered from least to greatest.
#
# * To find the median of the whole sample result, enter in a new cell:
#
#     Equation Info: =MEDIAN(*MEDIAN_RANGE*)
#
#     Our Dataset: =MEDIAN(O:O)
#
# ![SampleMedian.png](ExcelPics/SampleMedian.png)
#
# Range : the difference between the largest and smallest value of the data.
#
# * To find the range of the sample result, calculate the it by performing the equation MAXIMUM_RESULT - MINIMUM_RESULT. Enter in a new cell:
#
#     Equation Info: =MAX(*MAX_RANGE*) - MIN(*MIN_RANGE*)
#
#     Our Dataset: =MAX(O:O) - MIN(O:O)
#
# ![SampleRange](ExcelPics/SampleRange.png)

# %% [markdown]
# # FullPractical Data
# * Data that we will be using: [WaterData](./Data/WaterData.csv)

# %% [markdown]
# ## (Practical) How to Filter/Sort a Dataset
# * Datasets are usually filled with **irrelevant** data samples.
# * We must **filter out** the irrelevent data samples.
#
# Goal:
# * We want to filter out the data to show only TDS sample data.
#
# Step 1: We want to locate which parameter we should use to filter the data.
# * The sample classifies what the sample is measuring in the 'parameter' parameter.
#     * We will detect which samples measures TDS from this parameter
#
# ![ExcelParameterSelecting.png](ExcelPics/ExcelParameterSelecting.png)
#
# <a id='step2'></a>
# Step 2: Highlight this parameter and find all instances of Total Dissolved Solids (TDS)
# * Left-click mouse and click on 'Add or Remove Filters'
#
# ![FilterSearch.png](ExcelPics/FilterSearch.png)
#
# * Click on the downarrow on the right of the 'parameter' cell, then Text Filters -> Equals
#
# ![EqualsFilter.png](ExcelPics/EqualsFilter.png)
#
# * A new tab will pop up. Enter *Total Dissolved Solids* in the textbox next to the equals, and then press the ok button.
#
# ![FilterEquals.png](ExcelPics/FilterEquals.png)
#
# * The dataset will now be filtered to show only the TDS samples
#
# ![FilterResults.png](ExcelPics/FilterResults.png)

# %% [markdown]
# ## (Practical) How to Make Visualizations
# * Data visulaizations (through maps and graphs) are a great way to see the patterns, trends, and outliers of the data.
#
# Using the dataset [WaterData](./Data/WaterData.csv), we want to compare TDS and time.
#
# Step 1: We must filter the data to only TDS samples and by sample date.
#    * To filter multiple parameters, click the icon Data -> Filter
#    * To filter TDS:
#        * Click on the arrow next to the 'parameter' parameter and repeat the steps after [clicking on 'Text Filters' in 'How to Filter/Sort Data section'](#step2)
#
#        ![FilterMultiple.png](ExcelPics/FilterMulti.png)
#
#    * To filter time (oldest to newest):
#        * Click on thre arrow next to the 'sample_data' parameter and click 'Sort Oldest to Newest'
#
#        ![TimeSort.png](ExcelPics/TimeSort.png)
#
#
#  Step 2: Create the Graph
#  * Click on 'Insert' -> Scatter Picture -> 2nd Scatter Picture.
#
#     ![ScatterClick.png](ExcelPics/ScatterClick.png)
#
#
#  * Click 'Filter Icon'.
#
#      ![GraphFilter.png](ExcelPics/GraphFilter.png)
#
#
#  * Click 'Select Data'.
#
#      ![GraphSelectData.png](ExcelPics/GraphSelectData.png)
#
#
#  * Click 'Add'.
#
#      ![GraphAdd.png](ExcelPics/GraphAdd.png)
#
#
#  * Fill in the 'Series X values' and 'Series Y values' textbox with the following text, then click on 'ok'.
#
#      ![GraphSetAxis.png](ExcelPics/GraphSetAxis.png)
#
#
#  * Result:
#
#      ![GraphScatter.png](ExcelPics/GraphScatter.png)
#
#
#  Step 3: Add a trendline.
#  * Click on the chart, then click on 'Chart Design' -> 'Add Chart Element' -> 'Trendline' -> 'Linear'
#      * For trendline equation: Click on the chart, then click on 'Chart Design' -> 'Add Chart Element' -> 'Trendline' -> 'More Trendline Options'
#
#      ![GraphTrendlineOptions.png](ExcelPics/GraphTrendlineOptions.png)
#
#
#  * Click on 'Display Equation on Chart' checkbox.
#
#     ![GraphEquations.png](ExcelPics/GraphEquation.png)
#
#
#  * Result:
#
#     ![GraphTrendlineResult.png](ExcelPics/GraphTrendlineResult.png)

# %% [markdown]
# ## (Practical) Calculate Data Statistics
# * Data Statistics such as mean, median, and range of data can be easily found on Excel.
#
# *Mean*
# : is the average of a data set.
#
# * To find the mean of the whole sample result, enter in a new cell:
#
#     Equation Info: =AVERAGEIF(*CRITERIA_RANGE* , *AVERAGE_RANGE*)
#
#     Our Dataset: =AVERAGEIF(N:N,"Total Dissolved Solids" , O:O)
#
#     ![AverageCalculate.png](ExcelPics/AverageCalculate.png)
#
# *Median*
# : is the middle value of the data ordered from least to greatest.
#
# * To find the median of the whole sample result, enter in a new cell:
#
#     Equation Info: =MEDIAN(IF(*CRITERIA_RANGE* , *MEDIAN_RANGE*))
#
#     =MEDIAN(IF(N:N="Total Dissolved Solids" , O:O))
#
#     ![MedianCalculate.png](ExcelPics/MedianCalculate.png)
#
# *Range*
# : the difference between the largest and smallest value of the data.
#
# * To find the range of the sample result, calculate the it by performing the equation MAXIMUM_RESULT - MINIMUM_RESULT. Enter in a new cell:
#
#    Equation Info: =MAXIFS(*MAX_RANGE* , *CRITERIA_RANGE*) - MINIFS(*MIN_RANGE* , *CRITERIA_RANGE*)
#
#    Our Dataset: =MAXIFS(O:O , N:N,"Total Dissolved Solids") - MINIFS(O:O , N:N,"Total Dissolved Solids")
#
#    ![RangeCalculate.png](ExcelPics/RangeCalculate.png)
